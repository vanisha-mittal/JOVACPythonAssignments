# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_data=pd.read_csv('Titanic.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.histplot(titanic_data,x = 'Age',hue = 'Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.jointplot(titanic_data,x = 'Age',y = 'Fare',hue = 'Survived')

# %%
sns.countplot(titanic_data,x = 'Pclass',hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.jointplot(titanic_data,x='Pclass',y='Age',hue='Survived')

# %%
sns.jointplot(titanic_data,x='Pclass',y='Fare',hue='Survived')

# %%
sns.jointplot(titanic_data,x='Fare',y='Age',hue='Survived')

# %%
sns.jointplot(titanic_data,x='SibSp',y='Age',hue='Survived')

# %%
plt.figure(figsize=(20,20))
sns.pairplot(titanic_data,hue='Survived')

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')


for survive in np.unique(titanic_data['Survived']):
    subset = titanic_data[titanic_data['Survived'] == survive]
    ax.scatter(
        subset['Pclass'],
        subset['Age'],
        subset['SibSp'],
        label=survive
    )


ax.set_xlabel('Pclass')
ax.set_ylabel('Age')
ax.set_zlabel('Fare')


ax.legend()


plt.show()
